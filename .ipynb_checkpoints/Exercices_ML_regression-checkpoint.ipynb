# %% [markdown]
# # Notebook des exercices de machine Learning
#
# Ce notebook présente les exercices 1 et 2 concernant le TP sur la regression dans le cadre du cours de machine learning pour la classe ISE2 de l'ENSAE de Dakar.
#
# Il a été fait par **Larry SANDJO**

# %% [markdown]
# # Data Collection
#
# On collecte d'abord les données

# %%
from pathlib import Path

import matplotlib.pyplot as plt
import missingno as msno
import numpy as np
import pandas as pd
import plotly.express as px
import plotly.graph_objs as go
import seaborn as sns
from plotly.subplots import make_subplots
from ydata_profiling import ProfileReport
from yellowbrick.regressor import ResidualsPlot

# %%
# you must put the CSV file billets.csv in data directory, cf above cell
data = pd.read_csv("data/billets.csv", sep=";")
data.shape  # data frame dimensions (nb rows, nb columns)
# Out:
# (1500, 7)

# %%
from sklearn import linear_model

import statsmodels.formula.api as smf
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from statsmodels.stats.diagnostic import het_white , normal_ad

# %%
data_model = data.loc[lambda dfr: dfr.margin_low.notnull()]

data_model.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1463 entries, 0 to 1499
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   is_genuine    1463 non-null   bool
#  1   diagonal      1463 non-null   float64
#  2   height_left   1463 non-null   float64
#  3   height_right  1463 non-null   float64
#  4   margin_low    1463 non-null   float64
#  5   margin_up     1463 non-null   float64
#  6   length        1463 non-null   float64
# dtypes: bool(1), float64(6)
# memory usage: 81.4 KB

# %%
# Création des variables explicatives et cible:
# X est la liste des variables explicatives et y est la variable cible
X = data_model.loc[:, ["diagonal", "height_left", "height_right", "margin_up", "length"]]  # ou data.drop(["margin_low", "is_genuine"], axis=1)
y = data_model.loc[:, 'margin_low']

# %%
X.head()
# Out:
#    diagonal  height_left  height_right  margin_up  length
# 0    171.81       104.86        104.95       2.89  112.83
# 1    171.46       103.36        103.66       2.99  113.09
# 2    172.69       104.48        103.50       2.94  113.16
# 3    171.36       103.91        103.94       3.01  113.51
# 4    171.73       104.28        103.46       3.48  112.54

# %% [markdown]
# # Train/Test split

# %%
# Séparons nos données en un jeu d'entraînement et un jeu de test :
# 30% des données dans le jeu de test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

print(f"Train set - X: {X_train.shape} ; y: {y_train.shape} \nTest set - X: {X_test.shape} ; y: {y_test.shape}")
# Out:
# Train set - X: (1024, 5) ; y: (1024,)
# Test set - X: (439, 5) ; y: (439,)

# %% [markdown]
# ## Standardisation

# %%
# Standardisons les données :

std_scaler = StandardScaler().fit(X_train)  # Standardize features by removing the mean and scaling to unit variance.
X_train_std = std_scaler.transform(X_train)
X_test_std = std_scaler.transform(X_test)

# %% [markdown]
# ## Ridge

# %%
# On crée un modèle de régression linéaire
ridge = linear_model.Ridge(alpha=1.)

# On entraîne ce modèle sur les données d'entrainement
ridge.fit(X_train, y_train)

# On récupère l'erreur de norme 2 sur le jeu de données test
ridge_error = np.mean((ridge.predict(X_test) - y_test) ** 2)


# On obtient l'erreur quadratique ci-dessous
print(ridge_error)
# Out:
# 0.2162136226425013

# %%
mse = metrics.mean_squared_error(ridge.predict(X_test), y_test)
rmse = np.sqrt(mse)  # metrics.mean_squared_error(ridge.predict(X_test), y_test, squared=False)
mae = metrics.mean_absolute_error(ridge.predict(X_test), y_test)

mse, rmse, mae
# Out:
# (0.2162136226425013, 0.46498776612132636, 0.35629319455565117)

# %% [markdown]
# ## Définition d'une fonction d'entrainement

# %%
def train_model(model, x_train, y_train, x_test, y_test):
    # On entraîne ce modèle sur les données d'entrainement
    model.fit(x_train, y_train)
    
    # On récupère l'erreur de norme 2 sur le jeu de données train
    error_train = np.mean((model.predict(x_train) - y_train) ** 2)

    # On récupère l'erreur de norme 2 sur le jeu de données test
    error_test = np.mean((model.predict(x_test) - y_test) ** 2)

    # On obtient l'erreur quadratique ci-dessous
    print(f"Model error: {round(error_test, 5)}")
    return {"estimator": model, "error_train": error_train, "error_test": error_test}

# %%
# Train and evaluate ridge regression
ridge_error = train_model(model=linear_model.Ridge(alpha=1.),
                          x_train=X_train, y_train=y_train,
                          x_test=X_test, y_test=y_test)
# Out:
# Model error: 0.21621

# %% [markdown]
# ## Lasso

# %%
# Train and evaluate ridge regression
lasso_error = train_model(model=linear_model.Lasso(fit_intercept=True, alpha=1.,),
                          x_train=X_train, y_train=y_train,
                          x_test=X_test, y_test=y_test)
# Out:
# Model error: 0.42698

# %% [markdown]
# ## Elastic-Net

# %%
# Train and evaluate ridge regression
elastic_error = train_model(model=linear_model.ElasticNet(fit_intercept=True, alpha=1., l1_ratio=.5),
                            x_train=X_train_std, y_train=y_train,
                            x_test=X_test, y_test=y_test)
# Out:
# Model error: 0.42698
# C:\Users\Larry\anaconda3\Lib\site-packages\sklearn\base.py:432: UserWarning: X has feature names, but ElasticNet was fitted without feature names
#   warnings.warn(

# %% [markdown]
# # EXERCICE 1
#
# Dans la cellule précédente, veuillez analyser les variables explicatives: que constatez vous entre le jeu de train et le jeu de test?

# %% [markdown]
# Le premier constat est que pour entrainer le modèle elasticNet on a utilisé les données d'entraînement standardisés **X_train_std** mais par contre les données de test non standardisés **X_test**.
#
# Il est donc clair dans ce cas que les variables caractéristiques des variables dans le train et dans le test seront strictement différentes.
#
# D'après moi, le fait que les données test ne sont pas standardisés pourrait entraîner des erreurs de généralisation. Il faudrait aussi utiliser les données de test standardisés.

# %%
# ElascticNet avec données de test standardisés

elastic_error = train_model(model=linear_model.ElasticNet(fit_intercept=True, alpha=1., l1_ratio=.5),
                            x_train=X_train_std, y_train=y_train,
                            x_test=X_test_std, y_test=y_test)
# Out:
# Model error: 0.42698

# %% [markdown]
# On obtiens quasiment la même erreur qu'avec les données non standardisées.
# Nous allons essayer de comprendre pourquoi.
#
# Nous allons analyser les distributions des variables dans les données train standardisées et dans les données test non standardisées.

# %% [markdown]
# #### Statistiques descriptives des variables

# %%
feature_names = ['diagonal', 'height_left', 'height_right', 'margin_up', 'length']

# %%
# Transformation de X_train_std en DataFrame
X_train_std_df = pd.DataFrame(X_train_std, columns=feature_names)

# Affichage des statistiques descriptives
X_train_std_df.describe()
# Out:
#            diagonal   height_left  height_right     margin_up        length
# count  1.024000e+03  1.024000e+03  1.024000e+03  1.024000e+03  1.024000e+03
# mean  -1.272212e-13 -1.526557e-15  1.703152e-14  3.564857e-16  2.862294e-15
# std    1.000489e+00  1.000489e+00  1.000489e+00  1.000489e+00  1.000489e+00
# min   -3.030330e+00 -2.718062e+00 -3.096393e+00 -2.588439e+00 -3.100547e+00
# 25%   -7.053947e-01 -6.944951e-01 -6.769649e-01 -7.250201e-01 -7.226474e-01
# 50%   -7.914122e-03  1.333691e-02 -3.200143e-03 -7.499041e-02  3.144607e-01
# 75%    7.227799e-01  6.795318e-01  7.318160e-01  6.617099e-01  7.527964e-01
# max    3.080929e+00  2.811355e+00  3.151244e+00  3.261829e+00  1.884448e+00

# %%
X_test.describe()
# Out:
#          diagonal  height_left  height_right   margin_up      length
# count  439.000000   439.000000    439.000000  439.000000  439.000000
# mean   171.951754   104.020456    103.922483    3.143235  112.672802
# std      0.315320     0.297897      0.318636    0.232813    0.874626
# min    171.040000   103.140000    103.030000    2.270000  109.490000
# 25%    171.745000   103.825000    103.725000    2.980000  111.990000
# 50%    171.950000   104.030000    103.920000    3.140000  112.980000
# 75%    172.160000   104.230000    104.140000    3.320000  113.350000
# max    173.010000   104.830000    104.950000    3.770000  114.130000

# %% [markdown]
# Sans surprise, les données sont complètement différentes en terme d'échelle car l'une est standardisée contrairement à l'autre.
#
# **On va maintenant essayer de comparer les distributions dans chaque variables d'une part pour les données de train standardisées et d'autre part pour les données de test.**

# %% [markdown]
# #### Fonction pour tracer les distributions

# %%
def plot_distribution(variable_name, X_train_std, X_test, feature_names):
    X_train_std_df = pd.DataFrame(X_train_std, columns=feature_names)
    X_test_df = pd.DataFrame(X_test, columns=feature_names)
    
    if variable_name not in X_train_std_df.columns or variable_name not in X_test_df.columns:
        print(f"Erreur : La variable '{variable_name}' n'existe pas dans les jeux de données.")
        return

    fig, axes = plt.subplots(1, 2, figsize=(18, 6))

    sns.histplot(X_train_std_df[variable_name], kde=True, color='blue', bins=30, ax=axes[0], label=f'Train - {variable_name}')
    axes[0].set_title(f"Distribution de '{variable_name}' dans le jeu d'entraînement")
    axes[0].legend()

    sns.boxplot(x=X_train_std_df[variable_name], color='blue', ax=axes[1], width=0.3)
    axes[1].set_title(f"Boxplot de '{variable_name}' dans le jeu d'entraînement")

    plt.tight_layout()
    plt.show()

    fig, axes = plt.subplots(1, 2, figsize=(18, 6))  # 1 ligne, 2 colonnes

    sns.histplot(X_test_df[variable_name], kde=True, color='red', bins=30, ax=axes[0], label=f'Test - {variable_name}')
    axes[0].set_title(f"Distribution de '{variable_name}' dans le jeu de test")
    axes[0].legend()

    sns.boxplot(x=X_test_df[variable_name], color='red', ax=axes[1], width=0.3)
    axes[1].set_title(f"Boxplot de '{variable_name}' dans le jeu de test")

    plt.tight_layout()
    plt.show()

# %% [markdown]
# #### Distribution pour la variable 'diagonal'

# %%
plot_distribution('diagonal', X_train_std, X_test, feature_names)
# Out:
# C:\Users\Larry\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Larry\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# #### Distribution pour la variable 'height_left'

# %%
plot_distribution('height_left', X_train_std, X_test, feature_names)
# Out:
# C:\Users\Larry\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Larry\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# #### Distribution pour la variable 'height_right'

# %%
plot_distribution('height_right', X_train_std, X_test, feature_names)
# Out:
# C:\Users\Larry\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Larry\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# #### Distribution pour la variable 'margin_up'

# %%
plot_distribution('margin_up', X_train_std, X_test, feature_names)
# Out:
# C:\Users\Larry\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Larry\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# #### Distribution pour la variable 'length'

# %%
plot_distribution('length', X_train_std, X_test, feature_names)
# Out:
# C:\Users\Larry\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Larry\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ### Analyse des graphiques
# Globalement, on constate que les variables des données d'entraînement standardisés ont des distributions qui ne sont pas trop  à celles des données de test non standardisés. Cela pourrait expliquer pourquoi le résultat obtenu avec les données de train standardisées ne sont pas différents de cux obtenus avec les données de train non standardisées lors de l'entraînement du modèle.

# %% [markdown]
# # EXERCICE 2

# %% [markdown]
# - Optimiser les modèles Ridge, Lasso et ElasticNet
# - Etudier l'importance des variables dans chaque modèle
#
#
# A envoyer par mail:
# - Lien github vers le notebook
# - Objet: IML ISE - TP1 regression 2024
# au plus tard jeudi 18h

# %% [markdown]
# ## Optimisation du modèle  Ridge et importance des variables

# %%
# On va utiliser la fonction GridSearchCV

from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# On va ecrire une fonction qui nous donne les parametre optimums pour les modèles.
#
# Après plusieurs tentatives, on a constaté que le meilleur paramètre alpha se situe entre 0 et 20

# %%
def model_optimisation(model, type_scoring, x_train, y_train, range, x_test, y_test, feature_names):
    
    param_grid = {'alpha': range}
    
    grid_search = GridSearchCV(estimator=model, param_grid=param_grid, 
                                     scoring=type_scoring, cv=5, return_train_score=True)
    
    grid_search.fit(x_train, y_train)
    
    print("Meilleur alpha :", grid_search.best_params_)
    print("Meilleur score d'erreur :", grid_search.best_score_)

    best_ridge_model = grid_search.best_estimator_
    
    y_pred_test = best_ridge_model.predict(x_test)
    test_error = mean_squared_error(y_test, y_pred_test)
    r2 = r2_score(y_test, y_pred_test) 
    print("Erreur sur les données de test (MSE) :", test_error)
    print("Coefficient de détermination (R²) sur les données de test :", r2)

    coefficients = best_ridge_model.coef_
    
    # Tracé 
    results_ridge = grid_search.cv_results_
    alphas = results_ridge['param_alpha'].data
    mean_test_errors = -results_ridge['mean_test_score']
    
    fig = go.Figure()
    fig.add_trace(go.Scatter(x=alphas, y=mean_test_errors, mode='lines+markers', 
                             name='Erreur de test moyenne', line=dict(color='blue')))
    
    fig.update_layout(
        title="Erreur de test en fonction de Alpha",
        xaxis=dict(title="Alpha"),
        yaxis=dict(title="Erreur de test moyenne"),
        template="plotly_white"
    )
    
    fig.show()
    
    if feature_names is None:
        feature_names = [f'Feature {i}' for i in range(len(coefficients))]
    
    feature_importance = pd.DataFrame({
        'Variable': feature_names,
        'Importance': coefficients
    }).sort_values(by='Importance', ascending=False)

    
    fig = go.Figure()
    fig.add_trace(go.Bar(
        x=feature_importance['Variable'], 
        y=feature_importance['Importance'],
        name="Importance des variables",
        marker=dict(color='orange')
    ))

    fig.update_layout(
        title="Importance des variables pour le modèle optimisé",
        xaxis=dict(title="Variables"),
        yaxis=dict(title="Importance absolue des coefficients"),
        template="plotly_white"
    )
    
    fig.show()
    return feature_importance

# %% [markdown]
# ### En utilisant la MSE

# %%
model_optimisation(linear_model.Ridge(), "neg_mean_squared_error", X_train, y_train, np.linspace(1e-10, 20, 100), X_test, y_test, feature_names)
# Out:
# Meilleur alpha : {'alpha': 9.494949495002022}
# Meilleur score d'erreur : -0.24030135248384904
# Erreur sur les données de test (MSE) : 0.21612493019996884
# Coefficient de détermination (R²) sur les données de test : 0.49381112811597594
#        Variable  Importance
# 3     margin_up    0.246623
# 2  height_right    0.245428
# 1   height_left    0.167951
# 0      diagonal   -0.080679
# 4        length   -0.409167

# %% [markdown]
# ### Commentaire
# Le modèle de régression Ridge est optimisé pour alpha = 9.49 si l'optimisation se fait avec la MSE.
# Il présente des performances équilibrées et satisfaisantes, avec une erreur quadratique moyenne (MSE) modérée de 0.216 sur le jeu de test, légèrement inférieure à celle de validation croisée (-0.24), ce qui suggère une bonne capacité de généralisation sans surapprentissage.
# Le coefficient de détermination R2 de 0.4938 montre que le modèle explique environ 49,38 % de la variance des données.
#
#
# En analysant l'importance des variables, on se rend compte que margin_up (0.2466) et height_right (0.2454) sont les variables les plus influentes(positivement), contribuant positivement aux prédictions et indiquant probablement une corrélation importante avec la variable cible. height_left (0.1680) a une importance modérée mais positive, renforçant légèrement les prédictions. À l'inverse, length présente l’importance négative la plus élevée (-0.4092), suggérant une relation inverse marquée avec la cible, tandis que diagonal (-0.0807) a un impact négatif faible.

# %% [markdown]
# ### En utilisant la MAE

# %%
model_optimisation(linear_model.Ridge(), "neg_mean_absolute_error", X_train, y_train, np.linspace(1e-10, 30, 100), X_test, y_test, feature_names)
# Out:
# Meilleur alpha : {'alpha': 19.393939393974748}
# Meilleur score d'erreur : -0.38169619137232796
# Erreur sur les données de test (MSE) : 0.2162699293368952
# Coefficient de détermination (R²) sur les données de test : 0.4934715238441457
#        Variable  Importance
# 2  height_right    0.231665
# 3     margin_up    0.217424
# 1   height_left    0.159472
# 0      diagonal   -0.074427
# 4        length   -0.411165

# %% [markdown]
# ### Commentaire
#
# Le modèle de Ridge est optimisée pour alpha = 19.39 si loptimisation se fait avec la MAE.
# Il présente un score d'erreur de -0.3817 en validation croisée, ce qui indique une erreur plus élevée qu’avec l’alpha précédent, suggérant que cette valeur de alpha pourrait avoir pénalisé trop fortement les coefficients et réduit la flexibilité du modèle. Cependant, l'erreur sur les données de test (MSE) reste similaire à celle du modèle précédent, à 0.2163, et le coefficient de détermination R2 est également comparable, à 0.4935, montrant que le modèle explique environ 49,35 % de la variance des données de test. Ces résultats indiquent que, bien que l'augmentation de alpha ait un peu trop réduit l'ajustement du modèle sur les données d'entraînement, sa capacité à généraliser sur les données de test reste stable, suggérant que le modèle a trouvé un compromis raisonnable entre régularisation et performance.
#
# L'importance des variables n'a pas vraiment changé, l'ordre reste le même.

# %% [markdown]
# ### En utilisant R2

# %%
model_optimisation(linear_model.Ridge(), "r2", X_train, y_train, np.linspace(1e-10, 20, 100), X_test, y_test, feature_names)
# Out:
# Meilleur alpha : {'alpha': 8.686868686925253}
# Meilleur score d'erreur : 0.46027795574815433
# Erreur sur les données de test (MSE) : 0.21612260100189584
# Coefficient de détermination (R²) sur les données de test : 0.49381658335958833
#        Variable  Importance
# 3     margin_up    0.249527
# 2  height_right    0.246633
# 1   height_left    0.168677
# 0      diagonal   -0.081241
# 4        length   -0.408912

# %% [markdown]
# ### Commentaire
#
# Le modèle de Ridge est optimisé pour alpha = 8.69 si l'optimisation se fait à l'aide du R2.
# Il affiche un score d'erreur de 0.4603 en validation croisée. L'erreur sur les données de test (MSE) reste stable à 0.2161, similaire à celle obtenue avec les autres valeurs de alpha. Le coefficient de détermination R2 sur les données de test est de 0.4938, ce qui montre que le modèle explique environ 49,38 % de la variance des données, un score similaire aux autres essais. Ces résultats indiquent que la valeur d'alpha optimale trouvée ne perturbe pas significativement la capacité du modèle à généraliser et qu'il reste bien équilibré entre ajustement et régularisation.
#
# De même, il n'y a pas de changement significatif au niveau de la structure des erreurs constatées.

# %% [markdown]
# ## Optimisation du modèle Lasso et importance des variables

# %% [markdown]
# ### Avec la MSE
#
# Ici, on constate que la valeur optimale est très proche de zero

# %%
model_optimisation(linear_model.Lasso(), "neg_mean_squared_error", X_train, y_train, np.linspace(1e-16, 1, 100), X_test, y_test, feature_names)
# Out:
# Meilleur alpha : {'alpha': 1e-16}
# Meilleur score d'erreur : -0.24048559386935828
# Erreur sur les données de test (MSE) : 0.21624524016354482
# Coefficient de détermination (R²) sur les données de test : 0.49352934866238585
#        Variable  Importance
# 3     margin_up    0.288271
# 2  height_right    0.260365
# 1   height_left    0.176682
# 0      diagonal   -0.087867
# 4        length   -0.404925

# %% [markdown]
# ### Commentaire
# Le modèle de Lasso est optimisé pour alpha = 1e-16 si la métrique utilisé est la MSE.
# Il montre un très faible niveau de régularisation, quasiment équivalent à un modèle de régression linéaire ordinaire. Le score d'erreur de validation croisée de -0.2405 est légèrement inférieur à celui du modèle Ridge précédent, ce qui suggère que le modèle de Lasso avec un alpha aussi faible ajuste très bien les données d'entraînement, mais sans imposer de pénalité significative sur les coefficients. L'erreur sur les données de test (MSE) est de 0.2162, quaisment similaire à celle observée dans les autres modèles, indiquant que la performance du modèle reste stable en termes de prédiction. Le coefficient de détermination R2 sur les données de test est de 0.4935, ce qui montre que le modèle explique environ 49,35 % de la variance des données de test, un score très proche de celui des modèles Ridge précédents. Cela suggère que même avec une régularisation aussi faible, le modèle de Lasso parvient à expliquer une proportion similaire de la variance.
#
# Pour l'importance des variables, on constate une augmentation de l'importance des variables margin_up, et height_right.

# %% [markdown]
# ### Avec la MAE

# %%
model_optimisation(linear_model.Lasso(), "neg_mean_absolute_error", X_train, y_train, np.linspace(1e-16, 1, 100), X_test, y_test, feature_names)
# Out:
# Meilleur alpha : {'alpha': 1e-16}
# Meilleur score d'erreur : -0.3821096775474994
# Erreur sur les données de test (MSE) : 0.21624524016354482
# Coefficient de détermination (R²) sur les données de test : 0.49352934866238585
#        Variable  Importance
# 3     margin_up    0.288271
# 2  height_right    0.260365
# 1   height_left    0.176682
# 0      diagonal   -0.087867
# 4        length   -0.404925

# %% [markdown]
# ### Commentaire
# Le modèle de Lasso est optimisé pour alpha = 1e-16 en utilisant la métrique MAE.
# Il montre un score d'erreur de -0.3821 en validation croisée. Ce score suggère que, tout comme pour la métrique MSE, le modèle ajuste très bien les données d'entraînement sans pénaliser excessivement les coefficients, grâce à un paramètre de régularisation extrêmement faible (quasiment nul). L'erreur sur les données de test (MSE) reste stable à 0.2162, ce qui indique que la performance du modèle en termes de prédiction reste similaire. Le coefficient de détermination R2 sur les données de test est de 0.4935, identique à celui observé pour le modèle Ridge et pour la métrique MSE, signifiant que le modèle explique environ 49,35 % de la variance des données. Ces résultats confirment que l'absence de régularisation significative dans le modèle de Lasso n'affecte pas la capacité du modèle à généraliser, en obtenant des performances similaires à celles des autres modèles.
#
# Pas de remarques particulières au niveau des importances.

# %% [markdown]
# ### Avec le R2

# %%
model_optimisation(linear_model.Lasso(), "r2", X_train, y_train, np.linspace(1e-16, 1, 100), X_test, y_test, feature_names)
# Out:
# Meilleur alpha : {'alpha': 1e-16}
# Meilleur score d'erreur : 0.45991728947657223
# Erreur sur les données de test (MSE) : 0.21624524016354482
# Coefficient de détermination (R²) sur les données de test : 0.49352934866238585
#        Variable  Importance
# 3     margin_up    0.288271
# 2  height_right    0.260365
# 1   height_left    0.176682
# 0      diagonal   -0.087867
# 4        length   -0.404925

# %% [markdown]
# ### Commentaire
#
# Le modèle de Lasso est optimisé pour alpha = 1e-16 et la métrique R2. L'erreur sur les données de test (MSE) reste constante à 0.2162, ce qui montre que, tout comme avec les autres métriques, la capacité de prédiction du modèle est stable. Le coefficient de détermination R2 sur les données de test est de 0.4935, identique à celui obtenu dans les autres configurations, ce qui signifie que le modèle de Lasso explique environ 49,35 % de la variance des données de test. Cela montre que même avec une régularisation quasi inexistante, le modèle parvient à expliquer une proportion similaire de la variance des données.
#
# Pas de remarques particulières au niveau des importances.

# %% [markdown]
# #### Remarque
#
# On constate dans tous les cas que l'ordre d'importance des variables est la même, partant de **length** jusqu'à **diagonal**.

# %% [markdown]
# ## Optimisation du modèle ElasticNet et importance des variables

# %%
def elasticnet_optimisation(type_scoring, 
                            x_train, 
                            y_train, 
                            alpha_range, 
                            l1_ratio_range,
                            x_test, 
                            y_test, 
                            feature_names,
                            max_iter):
    
    param_grid = {'alpha': alpha_range, 'l1_ratio': l1_ratio_range}
    
    model = linear_model.ElasticNet(max_iter = max_iter)
    grid_search = GridSearchCV(estimator=model, param_grid=param_grid, 
                               scoring=type_scoring, cv=5, return_train_score=True)
    grid_search.fit(x_train, y_train)
    
    print("Meilleurs paramètres (alpha et l1_ratio) :", grid_search.best_params_)
    print("Meilleur score d'erreur :", grid_search.best_score_)
    
    results = grid_search.cv_results_
    alphas = results['param_alpha'].data
    l1_ratios = results['param_l1_ratio'].data
    mean_test_errors = -results['mean_test_score']
    best_model = grid_search.best_estimator_
    y_pred_test = best_model.predict(x_test)
    test_error = mean_squared_error(y_test, y_pred_test)
    r2 = r2_score(y_test, y_pred_test)
    print("Erreur sur les données de test (MSE) :", test_error)
    print("Coefficient de détermination (R²) sur les données de test :", r2)
    
    fig = go.Figure(data=[go.Surface(
        x=alphas, 
        y=l1_ratios, 
        z=mean_test_errors.reshape(len(l1_ratio_range), len(alpha_range)), 
        colorbar=dict(title="Erreur de test moyenne"),
        colorscale='Viridis'
    )])

    fig.update_layout(
        title="Erreur de test moyenne en fonction de Alpha et L1 Ratio",
        scene=dict(
            xaxis=dict(title="Alpha"),
            yaxis=dict(title="L1 Ratio"),
            zaxis=dict(title="Erreur de test moyenne"),
        ),
        template="plotly_white"
    )
    
    fig.show()


    coefficients = best_model.coef_
    
    if feature_names is None:
        feature_names = [f'Feature {i}' for i in range(len(coefficients))]
    
    feature_importance = pd.DataFrame({
        'Variable': feature_names,
        'Importance': coefficients
    }).sort_values(by='Importance', ascending=False)

    fig = go.Figure()
    fig.add_trace(go.Bar(
        x=feature_importance['Variable'], 
        y=feature_importance['Importance'],
        name="Importance des variables",
        marker=dict(color='orange')
    ))

    fig.update_layout(
        title="Importance des variables pour le modèle optimisé ElasticNet",
        xaxis=dict(title="Variables"),
        yaxis=dict(title="Importance absolue des coefficients"),
        template="plotly_white"
    )
    
    fig.show()
    return feature_importance

# %% [markdown]
# #### Avec la MSE

# %%
elasticnet_optimisation("neg_mean_squared_error", 
                    X_train, 
                    y_train,
                    np.linspace(0.1, 5, 50),
                    np.linspace(0.1, 0.9, 50),
                    X_test,
                    y_test,
                    feature_names,
                       100000)
# Out:
# Meilleurs paramètres (alpha et l1_ratio) : {'alpha': 0.1, 'l1_ratio': 0.1}
# Meilleur score d'erreur : -0.2474991793355707
# Erreur sur les données de test (MSE) : 0.22428713919273144
# Coefficient de détermination (R²) sur les données de test : 0.4746943174902635
#        Variable  Importance
# 2  height_right    0.126935
# 3     margin_up    0.072311
# 1   height_left    0.071142
# 0      diagonal   -0.000000
# 4        length   -0.407693

# %% [markdown]
# ### Commentaire
#
# Le modèle ElasticNet est optimisé pour les paramètres alpha = 0.1 et l1_ratio = 0.1.
# Il présente un score d'erreur de validation croisée de -0.2475, ce qui est légèrement inférieur à celui des modèles précédents, suggérant que ce modèle a ajusté les coefficients de manière modérée. L'erreur sur les données de test (MSE) est de 0.2243, indiquant une performance légèrement inférieure à celle des autres modèles, ce qui peut être attribué à la combinaison de la régularisation Ridge et Lasso qui réduit l'ajustement du modèle.
# Le coefficient de détermination R2 sur les données de test est de 0.4747, signifiant que le modèle explique environ 47,47 % de la variance des données de test. Ce score est inférieur à ceux observés pour les modèles Ridge et Lasso, ce qui suggère que l’ElasticNet, avec des paramètres alpha et l1_ratio choisis, n’est pas aussi performant en termes de capacité explicative sur ces données. Cela peut indiquer qu'une combinaison plus forte de L1 et L2 aurait pu améliorer les performances.
#
# L'analyse des importances pour le modèle ElasticNet montre que height_right (0.1269) est la variable la plus influente(positivement), contribuant positivement aux prédictions du modèle. Elle est suivie de margin_up (0.0723) et height_left (0.0711), qui ont des importances modérées et positives, renforçant les prédictions dans une moindre mesure. En revanche, length présente une importance négative élevée (-0.4077), ce qui suggère une relation inverse marquée avec la variable cible. La variable diagonal a une importance de 0, indiquant qu'elle n'a pratiquement aucun effet sur le modèle (elle pourrait être retirée). Globalement, height_right, margin_up, et height_left jouent un rôle positif dans les prédictions, tandis que length influence négativement les résultats, et diagonal n'affecte pas les prédictions du modèle.

# %% [markdown]
# ### Avec la MAE

# %%
elasticnet_optimisation("neg_mean_absolute_error", 
                    X_train, 
                    y_train,
                    np.linspace(0.1, 5, 50),
                    np.linspace(0.1, 0.9, 50),
                    X_test,
                    y_test,
                    feature_names,
                       100000)
# Out:
# Meilleurs paramètres (alpha et l1_ratio) : {'alpha': 0.1, 'l1_ratio': 0.1}
# Meilleur score d'erreur : -0.38589037415975563
# Erreur sur les données de test (MSE) : 0.22428713919273144
# Coefficient de détermination (R²) sur les données de test : 0.4746943174902635
#        Variable  Importance
# 2  height_right    0.126935
# 3     margin_up    0.072311
# 1   height_left    0.071142
# 0      diagonal   -0.000000
# 4        length   -0.407693

# %% [markdown]
# ### Commentaire
# Ici, on observe une augementation du score d'erreur de validation croisée qui est passé à -0.3859. L'erreur sur les données de test (MSE) est de 0.2243, similaire à celle observée dans le modèle précédemment. Le coefficient de détermination R2 sur les données de test est de 0.4747, indiquant que le modèle explique environ 47,47 % de la variance des données de test.
#
# Pas de changement significatif dans l'importance des variables.

# %% [markdown]
# ### Avec le r2

# %%
elasticnet_optimisation("r2", 
                    X_train, 
                    y_train,
                    np.linspace(0.1, 5, 50),
                    np.linspace(0.1, 0.9, 50),
                    X_test,
                    y_test,
                    feature_names,
                       100000)
# Out:
# Meilleurs paramètres (alpha et l1_ratio) : {'alpha': 0.1, 'l1_ratio': 0.1}
# Meilleur score d'erreur : 0.44368923876687666
# Erreur sur les données de test (MSE) : 0.22428713919273144
# Coefficient de détermination (R²) sur les données de test : 0.4746943174902635
#        Variable  Importance
# 2  height_right    0.126935
# 3     margin_up    0.072311
# 1   height_left    0.071142
# 0      diagonal   -0.000000
# 4        length   -0.407693

# %% [markdown]
# ### Commentaire
#
# Le modèle ElasticNet avec les meilleurs paramètres alpha = 0.1 et l1_ratio = 0.1, en utilisant la métrique R2. L'erreur sur les données de test (MSE) est de 0.2243, ce qui reste stable par rapport aux autres métriques et montre que la capacité prédictive du modèle est similaire à celle observée précédemment. Le coefficient de détermination R2 sur les données de test est de 0.4747, ce qui signifie que le modèle ElasticNet explique environ 47,47 % de la variance des données de test.
#
# Pas de changement significatif dans l'importance des variables.
